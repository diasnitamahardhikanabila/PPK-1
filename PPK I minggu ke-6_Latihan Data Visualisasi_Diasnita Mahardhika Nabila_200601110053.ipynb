# %% [markdown]
# ## Diasnita Mahardhika Nabila_200601110053
# ### Latihan Data Visualisasi

# %%
import numpy as np
import matplotlib.pyplot as plt

x=[18,19,20,21,22,23,24]
y=[20000,24000,26000,24000,28000,26000,24000]
plt.plot(x,y)

plt.xlabel('Tanggal')
plt.ylabel('Harga Minyak')
plt.title('Harga Minyak di Supermarket')
plt.text(21.5,28000,"Melonjaknya Harga Minyak")

plt.grid(True)
plt.show()
